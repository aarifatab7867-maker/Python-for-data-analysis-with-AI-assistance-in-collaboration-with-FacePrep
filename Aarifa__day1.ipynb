# %% [markdown]
# #day1

# %%
print("Python For Data Analysis with AI Assisstance")
# Out:
# Python For Data Analysis with AI Assisstance

# %%
name=input()
print(name)
# Out:
# Aarifa
# Aarifa

# %%
# Import required libraries

import numpy as np
import pandas as pd

print()
